# %%
pip install librosa
# Out:
# Requirement already satisfied: librosa in c:\users\drew\anaconda3\lib\site-packages (0.10.0.post2)
# Requirement already satisfied: joblib>=0.14 in c:\users\drew\anaconda3\lib\site-packages (from librosa) (1.1.0)
# Requirement already satisfied: decorator>=4.3.0 in c:\users\drew\anaconda3\lib\site-packages (from librosa) (5.1.1)
# Requirement already satisfied: soundfile>=0.12.1 in c:\users\drew\anaconda3\lib\site-packages (from librosa) (0.12.1)
# Requirement already satisfied: numba>=0.51.0 in c:\users\drew\anaconda3\lib\site-packages (from librosa) (0.55.1)
# Requirement already satisfied: pooch<1.7,>=1.0 in c:\users\drew\anaconda3\lib\site-packages (from librosa) (1.6.0)
# Requirement already satisfied: msgpack>=1.0 in c:\users\drew\anaconda3\lib\site-packages (from librosa) (1.0.3)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\users\drew\anaconda3\lib\site-packages (from librosa) (4.3.0)
# Requirement already satisfied: scipy>=1.2.0 in c:\users\drew\anaconda3\lib\site-packages (from librosa) (1.9.1)
# Requirement already satisfied: soxr>=0.3.2 in c:\users\drew\anaconda3\lib\site-packages (from librosa) (0.3.5)
# Requirement already satisfied: lazy-loader>=0.1 in c:\users\drew\anaconda3\lib\site-packages (from librosa) (0.3)
# Requirement already satisfied: audioread>=2.1.9 in c:\users\drew\anaconda3\lib\site-packages (from librosa) (3.0.0)
# Requirement already satisfied: scikit-learn>=0.20.0 in c:\users\drew\anaconda3\lib\site-packages (from librosa) (1.0.2)
# Requirement already satisfied: numpy!=1.22.0,!=1.22.1,!=1.22.2,>=1.20.3 in c:\users\drew\anaconda3\lib\site-packages (from librosa) (1.21.6)
# Requirement already satisfied: setuptools in c:\users\drew\anaconda3\lib\site-packages (from numba>=0.51.0->librosa) (63.4.1)
# Requirement already satisfied: llvmlite<0.39,>=0.38.0rc1 in c:\users\drew\anaconda3\lib\site-packages (from numba>=0.51.0->librosa) (0.38.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\drew\anaconda3\lib\site-packages (from pooch<1.7,>=1.0->librosa) (21.3)
# Requirement already satisfied: requests>=2.19.0 in c:\users\drew\anaconda3\lib\site-packages (from pooch<1.7,>=1.0->librosa) (2.28.1)
# Requirement already satisfied: appdirs>=1.3.0 in c:\users\drew\anaconda3\lib\site-packages (from pooch<1.7,>=1.0->librosa) (1.4.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\drew\anaconda3\lib\site-packages (from scikit-learn>=0.20.0->librosa) (2.2.0)
# Requirement already satisfied: cffi>=1.0 in c:\users\drew\anaconda3\lib\site-packages (from soundfile>=0.12.1->librosa) (1.15.1)
# Requirement already satisfied: pycparser in c:\users\drew\anaconda3\lib\site-packages (from cffi>=1.0->soundfile>=0.12.1->librosa) (2.21)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\drew\anaconda3\lib\site-packages (from packaging>=20.0->pooch<1.7,>=1.0->librosa) (3.0.9)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\drew\anaconda3\lib\site-packages (from requests>=2.19.0->pooch<1.7,>=1.0->librosa) (1.26.11)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\drew\anaconda3\lib\site-packages (from requests>=2.19.0->pooch<1.7,>=1.0->librosa) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\drew\anaconda3\lib\site-packages (from requests>=2.19.0->pooch<1.7,>=1.0->librosa) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\drew\anaconda3\lib\site-packages (from requests>=2.19.0->pooch<1.7,>=1.0->librosa) (2022.9.14)
# Note: you may need to restart the kernel to use updated packages.

# %%
import librosa
import numpy as np

def wav_to_piano_roll(wav_file_path, fs=100, threshold=0.1):
    """
    Convert a WAV file to a Piano Roll array.

    Args:
        wav_file_path (str): Path to the wav file.
        fs (int): Sampling frequency of the columns, i.e. each column is an interval of 1./fs seconds.
        threshold (float): Volume threshold for note on/off.

    Returns:
        np.ndarray: Piano roll of shape (128, T), where T is the number of time steps.
    """
    # Load the audio file
    y, sr = librosa.load(wav_file_path)

    # Compute the short-time Fourier transform
    stft = librosa.stft(y)

    # Convert the STFT into amplitude
    amplitude = np.abs(stft)

    # Convert to dB scale
    db = librosa.amplitude_to_db(amplitude)

    # Normalize to the range [0, 1]
    db_normalized = (db - db.min()) / (db.max() - db.min())

    # Map frequencies to MIDI notes
    freqs = librosa.fft_frequencies(sr=sr)

    # Only consider frequencies that fall within the MIDI note range (approximately 8 Hz to 12543 Hz)
    lo, hi = librosa.note_to_hz(['A0', 'G#8'])
    bins = np.where((freqs >= lo) & (freqs <= hi))

    freqs = freqs[bins]
    db_normalized = db_normalized[bins]

    # Map frequencies to MIDI notes
    midi_notes = librosa.hz_to_midi(freqs)

    # Round MIDI notes to the nearest integer
    midi_notes_rounded = np.round(midi_notes).astype(int)

    # Create an empty piano roll
    piano_roll = np.zeros((128, db_normalized.shape[1]))

    # Transfer DB values to piano roll
    for note, column in enumerate(db_normalized):
        if 0 <= midi_notes_rounded[note] < 128:
            piano_roll[midi_notes_rounded[note]] += column

    # Apply threshold to piano roll
    piano_roll = np.where(piano_roll >= threshold, piano_roll, 0)

    return piano_roll

# %%
badguy_recording_pianoroll = wav_to_piano_roll("Recording.wav", fs=100, threshold=0.1)
print(badguy_recording_pianoroll.shape)
# Out:
# (128, 1148)

# %%
def print_random_row(piano_roll):
    random_index = np.random.randint(piano_roll.shape[0])
    print(f"Row {random_index}: {list(piano_roll[random_index])}")
    
# Usage:
piano_roll = badguy_recording_pianoroll
print_random_row(piano_roll)
# Out:
# Row 43: [0.8066056370735168, 0.8742600679397583, 0.7767319679260254, 0.7172520160675049, 0.6764041781425476, 0.7255877256393433, 0.5280548930168152, 0.6995893716812134, 0.8347554206848145, 0.928173840045929, 0.9373718500137329, 0.9278669357299805, 0.9256173372268677, 0.9227226376533508, 0.9228765368461609, 0.9234737157821655, 0.9207242727279663, 0.8907787203788757, 0.966522216796875, 0.9240518808364868, 0.908482551574707, 0.7794966697692871, 0.7202707529067993, 0.72565758228302, 0.718366801738739, 0.6067366600036621, 0.6638385057449341, 0.8335555791854858, 0.9232746362686157, 0.9355373382568359, 0.9247257113456726, 0.9176847338676453, 0.9148653149604797, 0.9157147407531738, 0.9176455736160278, 0.9195352792739868, 0.8718467950820923, 0.947836697101593, 0.9546799659729004, 0.9518899917602539, 0.8928335309028625, 0.7275940775871277, 0.7931822538375854, 0.7801276445388794, 0.7243264317512512, 0.7095390558242798, 0.774975061416626, 0.926537036895752, 0.9617176055908203, 0.9606547355651855, 0.9550420641899109, 0.9501617550849915, 0.9489021301269531, 0.9489459991455078, 0.9488031268119812, 0.8844558000564575, 0.9482523202896118, 0.9619394540786743, 0.9277744293212891, 0.8798311948776245, 0.7735348343849182, 0.7751879692077637, 0.7596003413200378, 0.7128201723098755, 0.6884082555770874, 0.8430011868476868, 0.9420650601387024, 0.9638348817825317, 0.957258403301239, 0.9483698010444641, 0.942674458026886, 0.9397174715995789, 0.9399131536483765, 0.9406123161315918, 0.8967647552490234, 0.9199796915054321, 0.9651778936386108, 0.9005166888237, 0.8544797897338867, 0.7286298871040344, 0.8071802258491516, 0.7402641177177429, 0.7148305177688599, 0.6251295208930969, 0.7885190844535828, 0.9094301462173462, 0.9491257667541504, 0.9420894384384155, 0.9365917444229126, 0.9312006235122681, 0.9262096285820007, 0.926047146320343, 0.9285831451416016, 0.9059401750564575, 0.9203401803970337, 0.9592697024345398, 0.86346834897995, 0.7200666666030884, 0.7497249841690063, 0.8198385238647461, 0.8254523277282715, 0.8294490575790405, 0.8564367294311523, 0.8207336664199829, 0.8493039011955261, 0.8585572242736816, 0.8337832689285278, 0.8461700677871704, 0.853325366973877, 0.8462503552436829, 0.8467215299606323, 0.850615382194519, 0.840065598487854, 0.8624175190925598, 0.9518936276435852, 0.9382261037826538, 0.9560148119926453, 0.9033598899841309, 0.8875051736831665, 0.9088083505630493, 0.9195880889892578, 0.9088783264160156, 0.8994057774543762, 0.8969103693962097, 0.8979240655899048, 0.9046739339828491, 0.9042550921440125, 0.8823634386062622, 0.7787665128707886, 0.6425563097000122, 0.6556071639060974, 0.6602562665939331, 0.8977423906326294, 0.9549609422683716, 0.8933365941047668, 0.8896753191947937, 0.761441707611084, 0.7179162502288818, 0.7255244255065918, 0.6568334102630615, 0.4884273409843445, 0.6608354449272156, 0.8315726518630981, 0.8958908319473267, 0.9062089920043945, 0.8949747085571289, 0.8919826745986938, 0.8943477869033813, 0.8931649923324585, 0.8938566446304321, 0.899395763874054, 0.9251669049263, 0.9433611035346985, 0.8672090768814087, 0.8681640625, 0.7332980036735535, 0.7490732669830322, 0.67820143699646, 0.669337272644043, 0.46663975715637207, 0.6575199961662292, 0.7725698947906494, 0.8866521716117859, 0.9050790667533875, 0.8950382471084595, 0.8902870416641235, 0.8888139724731445, 0.8898893594741821, 0.8914688229560852, 0.8928754925727844, 0.8787055015563965, 0.9320709109306335, 0.9021593332290649, 0.8763823509216309, 0.7693199515342712, 0.6816523671150208, 0.7531417012214661, 0.7316211462020874, 0.6098370552062988, 0.6289470195770264, 0.680331826210022, 0.828647792339325, 0.8638499975204468, 0.8621070981025696, 0.8490009307861328, 0.8443619608879089, 0.8426634073257446, 0.8426313400268555, 0.843371570110321, 0.7969526052474976, 0.8713811635971069, 0.8589588403701782, 0.8279924392700195, 0.7408376932144165, 0.6321139335632324, 0.6607118248939514, 0.6629123687744141, 0.5964936017990112, 0.5705326199531555, 0.7386468648910522, 0.8426100611686707, 0.86056 ...

# %%
import os

def process_directory(directory_path):
    """
    Convert all .wav files in a directory to piano roll .txt files.

    Args:
        directory_path (str): Path to the directory.

    Returns:
        None
    """
    # List all files in the directory
    for filename in os.listdir(directory_path):
        # Check if the file is a .wav file
        if filename.endswith('.wav'):
            # Get the full path to the .wav file
            wav_file_path = os.path.join(directory_path, filename)
            
            # Convert the .wav file to a piano roll
            piano_roll = wav_to_piano_roll(wav_file_path)
            
            # Save the piano roll to a .txt file
            txt_file_path = os.path.join(directory_path, filename.replace('.wav', '.txt'))
            np.savetxt(txt_file_path, piano_roll)

    print(f"Processed all .wav files in {directory_path}")

process_directory('.wav_files')
# Out:
# Processed all .wav files in .wav_files
